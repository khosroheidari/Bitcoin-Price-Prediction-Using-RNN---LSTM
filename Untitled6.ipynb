# %% [markdown]
# <a href="https://colab.research.google.com/github/khosroheidari/Bitcoin-Price-Prediction-Using-RNN---LSTM/blob/master/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math
import pandas_datareader as web
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

# %%
data = pd.read_csv('//content/BTC-USD.csv', date_parser = True)
data.tail()
# Out:
#             Date          Open  ...     Adj Close       Volume
# 1823  2020-11-15  16068.139648  ...  15955.587891  23653867582
# 1824  2020-11-16  15955.577148  ...  16716.111328  31526766675
# 1825  2020-11-17  16685.691406  ...  17645.406250  39006849169
# 1826  2020-11-18  17645.191406  ...  17804.005859  49064800277
# 1827  2020-11-19  17705.250000  ...  17607.035156  42800037888
#
# [5 rows x 7 columns]

# %%
data_training = data[data['Date']< '2020-01-01'].copy()
data_training
# Out:
#             Date         Open  ...    Adj Close       Volume
# 0     2015-11-19   334.678986  ...   326.148987     45011100
# 1     2015-11-20   326.411011  ...   322.022003     53152900
# 2     2015-11-21   322.092010  ...   326.927002     28200500
# 3     2015-11-22   326.975006  ...   324.536011     23439400
# 4     2015-11-23   324.350006  ...   323.045990     27478900
# ...          ...          ...  ...          ...          ...
# 1499  2019-12-27  7238.141113  ...  7290.088379  22777360995
# 1500  2019-12-28  7289.031250  ...  7317.990234  21365673026
# 1501  2019-12-29  7317.647461  ...  7422.652832  22445257701
# 1502  2019-12-30  7420.272949  ...  7292.995117  22874131671
# 1503  2019-12-31  7294.438965  ...  7193.599121  21167946112
#
# [1504 rows x 7 columns]

# %%
data_test = data[data['Date']> '2020-01-01'].copy()
data_test
# Out:
#             Date          Open  ...     Adj Close       Volume
# 1505  2020-01-02   7202.551270  ...   6985.470215  20802083465
# 1506  2020-01-03   6984.428711  ...   7344.884277  28111481031
# 1507  2020-01-04   7345.375488  ...   7410.656738  18444271274
# 1508  2020-01-05   7410.451660  ...   7411.317383  19725074094
# 1509  2020-01-06   7410.452148  ...   7769.219238  23276261598
# ...          ...           ...  ...           ...          ...
# 1823  2020-11-15  16068.139648  ...  15955.587891  23653867582
# 1824  2020-11-16  15955.577148  ...  16716.111328  31526766675
# 1825  2020-11-17  16685.691406  ...  17645.406250  39006849169
# 1826  2020-11-18  17645.191406  ...  17804.005859  49064800277
# 1827  2020-11-19  17705.250000  ...  17607.035156  42800037888
#
# [323 rows x 7 columns]

# %%
training_data = data_training.drop(['Date', 'Adj Close'], axis = 1)
training_data.head()
# Out:
#          Open        High         Low       Close    Volume
# 0  334.678986  335.334015  325.273010  326.148987  45011100
# 1  326.411011  326.472992  312.217010  322.022003  53152900
# 2  322.092010  328.158997  319.595001  326.927002  28200500
# 3  326.975006  327.010010  321.259003  324.536011  23439400
# 4  324.350006  325.118011  321.290009  323.045990  27478900

# %%
scaler = MinMaxScaler()
training_data = scaler.fit_transform(training_data)
training_data
# Out:
# array([[7.63946522e-04, 6.21068351e-04, 6.99607873e-04, 3.18239778e-04,
#         4.78496061e-04],
#        [3.32328209e-04, 1.72770820e-04, 0.00000000e+00, 1.03038874e-04,
#         6.59094680e-04],
#        [1.06860675e-04, 2.58069310e-04, 3.95350842e-04, 3.58809242e-04,
#         1.05609090e-04],
#        ...,
#        [3.65300254e-01, 3.63802051e-01, 3.73362558e-01, 3.70364269e-01,
#         4.97353094e-01],
#        [3.70657677e-01, 3.60810844e-01, 3.73171949e-01, 3.63603289e-01,
#         5.06866230e-01],
#        [3.64088686e-01, 3.54763362e-01, 3.67463507e-01, 3.58420301e-01,
#         4.69020206e-01]])

# %%
X_train = []
Y_train = []

# %%
training_data.shape[0]
# Out:
# 1504

# %%
for i in range(60, training_data.shape[0]):
    X_train.append(training_data[i-60:i])
    Y_train.append(training_data[i,0])

# %%
X_train, Y_train = np.array(X_train), np.array(Y_train)

# %%
X_train.shape
# Out:
# (1444, 60, 5)

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout

# %%
regressor = Sequential()
regressor.add(LSTM(units = 50, activation = 'relu', return_sequences = True, input_shape = (X_train.shape[1], 5)))
regressor.add(Dropout(0.2))

# %%
regressor.add(LSTM(units = 60, activation = 'relu', return_sequences = True))
regressor.add(Dropout(0.3))

regressor.add(LSTM(units = 80, activation = 'relu', return_sequences = True))
regressor.add(Dropout(0.4))

regressor.add(LSTM(units = 120, activation = 'relu'))
regressor.add(Dropout(0.5))

regressor.add(Dense(units =1))

# %%
regressor.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# lstm (LSTM)                  (None, 60, 50)            11200
# _________________________________________________________________
# dropout (Dropout)            (None, 60, 50)            0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 60, 60)            26640
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 60, 60)            0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 60, 80)            45120
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 60, 80)            0
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 120)               96480
# ...

# %%
regressor.compile(optimizer = 'adam', loss = 'mean_squared_error')

# %%
regressor.fit(X_train, Y_train, epochs = 20, batch_size =50)
# Out:
# Epoch 1/20
# 29/29 [==============================] - 6s 208ms/step - loss: 0.0296
# Epoch 2/20
# 29/29 [==============================] - 6s 203ms/step - loss: 0.0087
# Epoch 3/20
# 29/29 [==============================] - 6s 204ms/step - loss: 0.0062
# Epoch 4/20
# 29/29 [==============================] - 6s 210ms/step - loss: 0.0061
# Epoch 5/20
# 29/29 [==============================] - 6s 209ms/step - loss: 0.0050
# Epoch 6/20
# 29/29 [==============================] - 6s 208ms/step - loss: 0.0051
# Epoch 7/20
# 29/29 [==============================] - 6s 206ms/step - loss: 0.0052
# Epoch 8/20
# 29/29 [==============================] - 6s 208ms/step - loss: 0.0048
# Epoch 9/20
# 29/29 [==============================] - 6s 207ms/step - loss: 0.0038
# Epoch 10/20
# 29/29 [==============================] - 6s 206ms/step - loss: 0.0038
# Epoch 11/20
# 29/29 [==============================] - 6s 203ms/step - loss: 0.0037
# Epoch 12/20
# ...

# %% [markdown]
# **Test** **Dataset**

# %%
past_60_days = data_training.tail(60)
df= past_60_days.append(data_test, ignore_index = True)
df = df.drop(['Date', 'Adj Close'], axis = 1)
df.head()
# Out:
#           Open         High          Low        Close       Volume
# 0  9259.783203  9377.486328  9249.587891  9324.717773  21242676385
# 1  9324.787109  9379.806641  9141.251953  9235.354492  21132220847
# 2  9235.607422  9505.051758  9191.485352  9412.612305  26170255634
# 3  9413.004883  9457.417969  9256.931641  9342.527344  26198609047
# 4  9340.864258  9423.237305  9305.909180  9360.879883  23133895764

# %%
inputs = scaler.transform(df)
inputs
# Out:
# array([[0.46668679, 0.45808231, 0.47891047, 0.46954713, 0.47067785],
#        [0.47008023, 0.4581997 , 0.47310527, 0.4648873 , 0.46822776],
#        [0.46542473, 0.46453611, 0.47579703, 0.47413038, 0.57997972],
#        ...,
#        [0.85434616, 0.88333063, 0.87088362, 0.90342807, 0.86471664],
#        [0.90443554, 0.91424387, 0.91312809, 0.91169822, 1.08781867],
#        [0.90757082, 0.89574535, 0.92674563, 0.90142721, 0.94885586]])

# %%
X_test = []
Y_test = []
for i in range (60, inputs.shape[0]):
    X_test.append(inputs[i-60:i])
    Y_test.append(inputs[i, 0])

# %%
X_test, Y_test = np.array(X_test), np.array(Y_test)
X_test.shape, Y_test.shape
# Out:
# ((323, 60, 5), (323,))

# %%
Y_pred = regressor.predict(X_test)
Y_pred, Y_test
# Out:
# (array([[0.32214412],
#         [0.32158646],
#         [0.3210582 ],
#         [0.32048562],
#         [0.31988811],
#         [0.31956917],
#         [0.32030764],
#         [0.32287824],
#         [0.3268873 ],
#         [0.3319517 ],
#         [0.33744636],
#         [0.34264544],
#         [0.34703806],
#         [0.35190538],
#         [0.35800126],
#         [0.36481425],
#         [0.3719716 ],
#         [0.37880835],
#         [0.38482994],
#         [0.38925886],
#         [0.39165288],
#         [0.39195988],
#         [0.39052305],
#         [0.3877359 ],
#         [0.38385278],
#         [0.37937123],
#         [0.375268  ],
#         [0.3727068 ],
#         [0.37221792],
#         [0.3740522 ],
#         [0.3778126 ],
#         [0.38262108],
#         [0.38790223],
#         [0.39316753],
#         [0.3979165 ],
#         [0.40222728],
#         [0.40644023],
#         [0.41061732],
#         [0.4147329 ],
#         [0.4188212 ],
#         [0.4229766 ],
# ...

# %%
scaler.scale_
# Out:
# array([5.22036307e-05, 5.05920740e-05, 5.35851619e-05, 5.21448360e-05,
#        2.21816575e-11])

# %%
scale = 1/5.18164146e-05
scale
# Out:
# 19298.903787912797

# %%
Y_test = Y_test*scale
Y_pred = Y_pred*scale

# %%
Y_pred
# Out:
# array([[ 6217.0283],
#        [ 6206.266 ],
#        [ 6196.072 ],
#        [ 6185.0215],
#        [ 6173.49  ],
#        [ 6167.335 ],
#        [ 6181.5864],
#        [ 6231.1963],
#        [ 6308.567 ],
#        [ 6406.304 ],
#        [ 6512.345 ],
#        [ 6612.6816],
#        [ 6697.454 ],
#        [ 6791.388 ],
#        [ 6909.032 ],
#        [ 7040.515 ],
#        [ 7178.6445],
#        [ 7310.586 ],
#        [ 7426.7964],
#        [ 7512.2695],
#        [ 7558.4717],
#        [ 7564.396 ],
#        [ 7536.667 ],
#        [ 7482.878 ],
#        [ 7407.938 ],
#        [ 7321.449 ],
#        [ 7242.261 ],
#        [ 7192.833 ],
#        [ 7183.398 ],
#        [ 7218.7974],
#        [ 7291.369 ],
#        [ 7384.1675],
#        [ 7486.088 ],
#        [ 7587.7026],
#        [ 7679.3525],
#        [ 7762.546 ],
#        [ 7843.851 ],
#        [ 7924.4644],
#        [ 8003.8906],
#        [ 8082.79  ],
#        [ 8162.9854],
#        [ 8242.427 ],
#        [ 8326.512 ],
# ...

# %%
Y_test
# Out:
# array([ 6933.93816888,  6714.18561351,  7077.82969032,  7143.39216656,
#         7143.3926582 ,  7504.29963682,  7900.49177719,  7820.25699333,
#         7614.74433925,  7900.74905654,  7770.85638945,  7928.53622053,
#         7879.33238717,  8568.85752777,  8555.89910474,  8467.97545435,
#         8671.48693691,  8685.82669992,  8447.24355219,  8401.26186181,
#         8487.11842273,  8423.08289753,  8145.94423647,  8180.75419445,
#         8104.47944784,  8339.11830009,  8656.68967948,  9104.96098374,
#         9063.19710261,  9256.93098262,  9093.7646549 ,  9137.55233741,
#         9092.07831864,  9039.84911586,  8929.60561281,  9367.25712967,
#         9476.24719546,  9543.8157627 ,  9615.16923921,  9868.71493238,
#         9607.10650555,  9956.19191062, 10078.67365178,  9965.42347095,
#        10068.49364946,  9640.6433483 ,  9688.37827718,  9441.2148852 ,
#         9897.16521801,  9378.84700259,  9361.17293869,  9437.66511709,
# ...

# %%
plt.figure(figsize=(14,5))
plt.plot(Y_test, color = 'red', label = 'Real Bitcoin Price')
plt.plot(Y_pred, color = 'green', label = 'Predicted Bitcoin Price')
plt.title('Bitcoin Price Prediction using RNN-LSTM')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()
